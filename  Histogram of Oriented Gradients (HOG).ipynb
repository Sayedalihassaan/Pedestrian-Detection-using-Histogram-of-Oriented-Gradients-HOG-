# %%
import cv2

# %%
img = cv2.imread(r"D:\Downloads\images\pexels-photo-109919.jpeg")
img = cv2.resize(img , (800,600))


def main():
    
    hog = cv2.HOGDescriptor()
    
    hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
    
    
    (bounding_boxes , weights) = hog.detectMultiScale(img,
                                                     winStride=(4,4),
                                                     padding=(8,8),
                                                     scale=1.05)
    
    
    for (x,y,w,h) in bounding_boxes:
        cv2.rectangle(img,
                 (x,y),
                     (x+w , y+h),
                     (0,0,255),
                      3)
    
    cv2.imshow("img" , img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

main()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 2
#       1 img = cv2.imread(r"D:\Downloads\images\pexels-photo-109919.jpeg")
# ----> 2 img = cv2.resize(img , (800,600))
#       5 def main():
#       7     hog = cv2.HOGDescriptor()
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
from imutils.object_detection import non_max_suppression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from imutils.object_detection import non_max_suppression
#
# ModuleNotFoundError: No module named 'imutils'
